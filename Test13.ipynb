# %%
import pandas as pd

# %%
credit = pd.read_csv("../../Downloads/Credit card transactions - India - Simple.csv")

# %%
credit.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India   5-May-15       Gold    Bills      F  171574

# %%
credit['City'].value_counts()
# Out:
# Bengaluru, India          3552
# Greater Mumbai, India     3493
# Ahmedabad, India          3491
# Delhi, India              3482
# Hyderabad, India           784
#                           ...
# Rayagada, India              1
# Varanasi, India              1
# Hugli-Chinsurah, India       1
# Alirajpur, India             1
# Fazilka, India               1
# Name: City, Length: 986, dtype: int64

# %%
hyd_data = credit[credit['City'] == 'Hyderabad, India']

# %%
hyd_data=hyd_data[:20]

# %%
hyd_data
# Out:
#        index              City       Date  Card Type Exp Type Gender  Amount
# 14649  14649  Hyderabad, India   2-Dec-13       Gold    Bills      F  220815
# 16523  16523  Hyderabad, India  21-May-14   Platinum  Grocery      F  114576
# 17174  17174  Hyderabad, India  22-Dec-13     Silver     Food      M  231638
# 17396  17396  Hyderabad, India   9-Dec-13       Gold  Grocery      F   88406
# 17869  17869  Hyderabad, India  25-Mar-14   Platinum     Food      M  123042
# 18795  18795  Hyderabad, India  20-Oct-13     Silver    Bills      F  172571
# 18969  18969  Hyderabad, India  17-Feb-14       Gold     Food      F   46844
# 19999  19999  Hyderabad, India  17-Feb-14       Gold    Bills      F  287938
# 20012  20012  Hyderabad, India  20-Jan-15     Silver    Bills      F  201657
# 20022  20022  Hyderabad, India  23-May-14   Platinum    Bills      F  180310
# 20028  20028  Hyderabad, India   2-Feb-14  Signature  Grocery      M  262828
# ...

# %%
hyd_data.sort_values(by='Date', inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5472\1779621008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyd_data.sort_values(by='Date', inplace=True)

# %%
hyd_data
# Out:
#        index              City       Date  Card Type Exp Type Gender  Amount
# 20101  20101  Hyderabad, India  12-Feb-15       Gold     Fuel      F  287753
# 20076  20076  Hyderabad, India  15-Sep-14       Gold  Grocery      M  231749
# 20089  20089  Hyderabad, India  16-Jul-14   Platinum     Food      F   47776
# 18969  18969  Hyderabad, India  17-Feb-14       Gold     Food      F   46844
# 19999  19999  Hyderabad, India  17-Feb-14       Gold    Bills      F  287938
# 20116  20116  Hyderabad, India  18-Jul-14   Platinum     Fuel      F   22092
# 14649  14649  Hyderabad, India   2-Dec-13       Gold    Bills      F  220815
# 20028  20028  Hyderabad, India   2-Feb-14  Signature  Grocery      M  262828
# 20012  20012  Hyderabad, India  20-Jan-15     Silver    Bills      F  201657
# 18795  18795  Hyderabad, India  20-Oct-13     Silver    Bills      F  172571
# 20057  20057  Hyderabad, India  20-Oct-14  Signature     Fuel      F   35502
# ...

# %%
import matplotlib.pyplot as plt

# %%
hyd_data.plot(x='Date', y='Amount')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.bar(x='Card Type', y='Gender')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 plt.bar(x='Card Type', y='Gender')
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
credit.columns
# Out:
# Index(['index', 'City', 'Date', 'Card Type', 'Exp Type', 'Gender', 'Amount',
#        'month'],
#       dtype='object')

# %%
df_2 = credit.groupby(['City'])['Card Type'].value_counts()

# %%
df_3 = pd.DataFrame(df_2)

# %%
df_3
# Out:
#                             Card Type
# City             Card Type
# Achalpur, India  Gold               4
#                  Signature          3
#                  Platinum           1
#                  Silver             1
# Adilabad, India  Signature          5
# ...                               ...
# Zira, India      Signature          1
#                  Silver             1
# Zirakpur, India  Platinum           3
# Zunheboto, India Silver             2
#                  Signature          1
#
# [3104 rows x 1 columns]

# %%
df_4 = credit['Card Type'].value_counts().reset_index()

# %%
df_4
# Out:
#        index  Card Type
# 0     Silver       6840
# 1  Signature       6447
# 2   Platinum       6398
# 3       Gold       6367

# %%
x = df_4['index']
y = df_4['Card Type']

# %%
df_1=credit['City'].value_counts()[:10].reset_index()

# %%
df_1
# Out:
#                    index  City
# 0       Bengaluru, India  3552
# 1  Greater Mumbai, India  3493
# 2       Ahmedabad, India  3491
# 3           Delhi, India  3482
# 4       Hyderabad, India   784
# 5         Chennai, India   774
# 6         Kolkata, India   773
# 7          Kanpur, India   764
# 8         Lucknow, India   759
# 9          Jaipur, India   752

# %%
x = df_1['index']
y = df_1['City']

# %%
plt.figure(figsize=(18, 12))
plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
credit.groupby('City').count()
# Out:
#                   index  Date  Card Type  Exp Type  Gender  Amount
# City
# Achalpur, India       9     9          9         9       9       9
# Adilabad, India      10    10         10        10      10      10
# Adityapur, India      6     6          6         6       6       6
# Adoni, India          9     9          9         9       9       9
# Adoor, India          7     7          7         7       7       7
# ...                 ...   ...        ...       ...     ...     ...
# Zaidpur, India        5     5          5         5       5       5
# Zamania, India        6     6          6         6       6       6
# Zira, India           9     9          9         9       9       9
# Zirakpur, India       3     3          3         3       3       3
# Zunheboto, India      3     3          3         3       3       3
#
# [986 rows x 6 columns]

# %%
credit['City'].value_counts()
# Out:
# Bengaluru, India          3552
# Greater Mumbai, India     3493
# Ahmedabad, India          3491
# Delhi, India              3482
# Hyderabad, India           784
#                           ...
# Rayagada, India              1
# Varanasi, India              1
# Hugli-Chinsurah, India       1
# Alirajpur, India             1
# Fazilka, India               1
# Name: City, Length: 986, dtype: int64

# %%
obj = credit.groupby(['City','Card Type'])['Gender'].count()

# %%
obj.first()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 obj.first()
#
# TypeError: first() missing 1 required positional argument: 'offset'

# %%
credit.groupby(['City','Card Type'])['Gender'].count().reset_index()
# Out:
#                   City  Card Type  Gender
# 0      Achalpur, India       Gold       4
# 1      Achalpur, India   Platinum       1
# 2      Achalpur, India  Signature       3
# 3      Achalpur, India     Silver       1
# 4      Adilabad, India       Gold       1
# ...                ...        ...     ...
# 3099       Zira, India  Signature       1
# 3100       Zira, India     Silver       1
# 3101   Zirakpur, India   Platinum       3
# 3102  Zunheboto, India  Signature       1
# 3103  Zunheboto, India     Silver       2
#
# [3104 rows x 3 columns]

# %%
credit['Amount'].describe()
# Out:
# count     26052.000000
# mean     156411.537425
# std      103063.254287
# min        1005.000000
# 25%       77120.250000
# 50%      153106.500000
# 75%      228050.000000
# max      998077.000000
# Name: Amount, dtype: float64

# %%
hyd_data.query('City=="Hyderabad, India"')
# Out:
#        index              City       Date  Card Type Exp Type Gender  Amount
#